# %%
import pandas as pd

# %% [markdown]
# ## 계획
# ### 삭제처리
# + 쓸모없는 칼럼 삭제
# + "-" 삭제
# ### 라벨링
# + 라벨인코딩
# + 원핫인코딩
# + 각각의 라벨링을 실행해보고 베이스라인 모델을 실행
# + mae를 낮추기 위해서 어떻게 해야하는지 고민
#     + 공부가 좀 더 필요함.

# %% [markdown]
# ## 쓸모없는 칼럼 삭제

# %%
df_test = pd.read_parquet('./test.parquet')

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

test = df_test[df_col]

test
# Out:
#         base_date  base_hour day_of_week  road_in_use  lane_count  \
# 0        20220825         17           목            0           3
# 1        20220809         12           화            0           2
# 2        20220805          2           금            0           1
# 3        20220818         23           목            0           3
# 4        20220810         17           수            0           3
# ...           ...        ...         ...          ...         ...
# 291236   20220827          5           토            0           1
# 291237   20220819         20           금            0           2
# 291238   20220805         11           금            0           1
# 291239   20220812          7           금            0           2
# 291240   20220812         10           금            0           3
#
#         road_rating  multi_linked  connect_code  maximum_speed_limit  \
# 0               107             0             0                 70.0
# 1               103             0             0                 70.0
# 2               103             0             0                 60.0
# 3               103             0             0                 70.0
# 4               106             0             0                 70.0
# ...             ...           ...           ...                  ...
# 291236          103             0             0                 80.0
# 291237          103             0             0                 60.0
# 291238          107             0             0                 30.0
# 291239          107             0             0                 60.0
# 291240          106             0             0                 70.0
#
#         weight_restricted  road_type  start_latitude  start_longitude  \
# 0                     0.0          0       33.499427       126.541298
# 1                     0.0          3       33.258507       126.427003
# 2                     0.0          0       33.258960       126.476508
# 3                     0.0          0       33.473494       126.545647
# 4                     0.0          0       33.501477       126.569223
# ...                   ...        ...             ...              ...
# 291236                0.0          0       33.472819       126.463030
# 291237                0.0          0       33.305359       126.598914
# 291238                0.0          0       33.493624       126.496769
# 291239                0.0          0       33.254782       126.507014
# 291240                0.0          0       33.246996       126.524358
#
#        start_turn_restricted  end_latitude  end_longitude end_turn_restricted  \
# 0                         없음     33.500772     126.543837                  있음
# 1                         없음     33.258119     126.415840                  없음
# 2                         없음     33.259206     126.474687                  없음
# 3                         없음     33.471061     126.545467                  없음
# 4                         없음     33.496863     126.581230                  없음
# ...                      ...           ...            ...                 ...
# 291236                    없음     33.470483     126.460846                  없음
# 291237                    없음     33.300796     126.600332                  없음
# 291238                    있음     33.497500     126.496946                  있음
# 291239                    없음     33.255659     126.507333                  없음
# 291240                    없음     33.247053     126.523503                  없음
#
#         road_name start_node_name end_node_name
# 0             연삼로            산지2교       제주은행사거리
# 1        일반국도12호선            중문입구        관광단지입구
# 2        일반국도16호선            도순3교          도순2교
# 3        일반국도11호선         아라주공아파트          인다마을
# 4             번영로         부록교 시종점       봉개교 시종점
# ...           ...             ...           ...
# 291236   일반국도16호선            월산마을           도근교
# 291237   일반국도11호선             영주교       하례입구삼거리
# 291238        신대로          마리나사거리       칠오광장사거리
# 291239        경찰로      국민의료보험관리공단        의료보험조합
# 291240  지방도1132호선          수모루교차로           수모루
#
# [291241 rows x 20 columns]

# %%
df_train = pd.read_parquet('./train.parquet')

# 쓸모없는 칼럼 삭제
df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name",
          "target"]

train = df_train[df_col]

train
# Out:
#          base_date  base_hour day_of_week  road_in_use  lane_count  \
# 0         20220623         17           목            0           1
# 1         20220728         21           목            0           2
# 2         20211010          7           일            0           2
# 3         20220311         13           금            0           2
# 4         20211005          8           화            0           2
# ...            ...        ...         ...          ...         ...
# 4701212   20211104         16           목            0           1
# 4701213   20220331          2           목            0           2
# 4701214   20220613         22           월            0           2
# 4701215   20211020          2           수            0           2
# 4701216   20211019          6           화            0           2
#
#          road_rating  multi_linked  connect_code  maximum_speed_limit  \
# 0                106             0             0                 60.0
# 1                103             0             0                 60.0
# 2                103             0             0                 80.0
# 3                107             0             0                 50.0
# 4                103             0             0                 80.0
# ...              ...           ...           ...                  ...
# 4701212          107             0             0                 50.0
# 4701213          107             0             0                 80.0
# 4701214          103             0             0                 60.0
# 4701215          103             0             0                 80.0
# 4701216          107             0             0                 60.0
#
#          weight_restricted  ...  start_latitude  start_longitude  \
# 0                  32400.0  ...       33.427747       126.662612
# 1                      0.0  ...       33.500730       126.529107
# 2                      0.0  ...       33.279145       126.368598
# 3                      0.0  ...       33.246081       126.567204
# 4                      0.0  ...       33.462214       126.326551
# ...                    ...  ...             ...              ...
# 4701212                0.0  ...       33.422145       126.278125
# 4701213            43200.0  ...       33.472505       126.424368
# 4701214                0.0  ...       33.447183       126.912579
# 4701215                0.0  ...       33.443596       126.431817
# 4701216                0.0  ...       33.256785       126.508940
#
#          start_turn_restricted end_latitude  end_longitude  \
# 0                           없음    33.427749     126.662335
# 1                           있음    33.504811     126.526240
# 2                           없음    33.280072     126.362147
# 3                           없음    33.245565     126.566228
# 4                           없음    33.462677     126.330152
# ...                        ...          ...            ...
# 4701212                     없음    33.420955     126.273750
# 4701213                     없음    33.472525     126.424890
# 4701214                     없음    33.444121     126.912948
# 4701215                     없음    33.444996     126.433332
# 4701216                     없음    33.257130     126.510364
#
#          end_turn_restricted  road_name start_node_name end_node_name target
# 0                         없음  지방도1112호선           제3교래교         제3교래교   52.0
# 1                         없음   일반국도11호선           광양사거리        KAL사거리   30.0
# 2                         없음   일반국도16호선            창고천교          상창육교   61.0
# 3                         없음        태평로           남양리조트          서현주택   20.0
# 4                         없음   일반국도12호선            애월샷시          애월입구   38.0
# ...                      ...        ...             ...           ...    ...
# 4701212                   없음          -           대림사거리          금덕해운   20.0
# 4701213                   없음          -             광삼교           광삼교   65.0
# 4701214                   없음   일반국도12호선           고성교차로         성산교차로   30.0
# 4701215                   없음   일반국도95호선           제6광령교        관광대학입구   73.0
# 4701216                   없음        경찰로          서귀포경찰서          시민공원   35.0
#
# [4701217 rows x 21 columns]

# %% [markdown]
# ## "-" 처리

# %% [markdown]
# ## 라벨 인코딩

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

for i in df_col:
    le = LabelEncoder()
    le=le.fit(train[i])
    train[i]=le.transform(train[i])
    
    for label in np.unique(test[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test[i]=le.transform(test[i])
# Out:
# C:\Users\tmdgh\AppData\Local\Temp/ipykernel_22164/4158976890.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i]=le.transform(train[i])
# C:\Users\tmdgh\AppData\Local\Temp/ipykernel_22164/4158976890.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[i]=le.transform(test[i])

# %%
train
# Out:
#          base_date  base_hour  day_of_week  road_in_use  lane_count  \
# 0              242         17            1            0           0
# 1              277         21            1            0           1
# 2               39          7            4            0           1
# 3              168         13            0            0           1
# 4               34          8            6            0           1
# ...            ...        ...          ...          ...         ...
# 4701212         64         16            1            0           0
# 4701213        188          2            1            0           1
# 4701214        232         22            3            0           1
# 4701215         49          2            2            0           1
# 4701216         48          6            6            0           1
#
#          road_rating  multi_linked  connect_code  maximum_speed_limit  \
# 0                  1             0             0                    3
# 1                  0             0             0                    3
# 2                  0             0             0                    5
# 3                  2             0             0                    2
# 4                  0             0             0                    5
# ...              ...           ...           ...                  ...
# 4701212            2             0             0                    2
# 4701213            2             0             0                    5
# 4701214            0             0             0                    3
# 4701215            0             0             0                    5
# 4701216            2             0             0                    3
#
#          weight_restricted  ...  start_latitude  start_longitude  \
# 0                        1  ...             323              464
# 1                        0  ...             523              322
# 2                        0  ...             144              102
# 3                        0  ...               9              388
# 4                        0  ...             392               68
# ...                    ...  ...             ...              ...
# 4701212                  0  ...             317               55
# 4701213                  2  ...             422              160
# 4701214                  0  ...             363              580
# 4701215                  0  ...             355              175
# 4701216                  0  ...              81              273
#
#          start_turn_restricted  end_latitude  end_longitude  \
# 0                            0           324            462
# 1                            1           532            321
# 2                            0           146            100
# 3                            0             7            388
# 4                            0           394             72
# ...                        ...           ...            ...
# 4701212                      0           314             52
# 4701213                      0           422            161
# 4701214                      0           356            581
# 4701215                      0           357            177
# 4701216                      0            83            281
#
#          end_turn_restricted  road_name  start_node_name  end_node_name  \
# 0                          0         46              386            386
# 1                          0         34               32              2
# 2                          0         36              426            179
# 3                          0         57               58            203
# 4                          0         35              267            269
# ...                      ...        ...              ...            ...
# 4701212                    0          0               79             42
# 4701213                    0          0               31             31
# 4701214                    0         35               19            214
# 4701215                    0         37              392             23
# 4701216                    0          1              190            247
#
#          target
# 0          52.0
# 1          30.0
# 2          61.0
# 3          20.0
# 4          38.0
# ...         ...
# 4701212    20.0
# 4701213    65.0
# 4701214    30.0
# 4701215    73.0
# 4701216    35.0
#
# [4701217 rows x 21 columns]

# %%
test
# Out:
#         base_date  base_hour  day_of_week  road_in_use  lane_count  \
# 0             305         17            1            0           2
# 1             289         12            6            0           1
# 2             285          2            0            0           0
# 3             298         23            1            0           2
# 4             290         17            2            0           2
# ...           ...        ...          ...          ...         ...
# 291236        307          5            5            0           0
# 291237        299         20            0            0           1
# 291238        285         11            0            0           0
# 291239        292          7            0            0           1
# 291240        292         10            0            0           2
#
#         road_rating  multi_linked  connect_code  maximum_speed_limit  \
# 0                 2             0             0                    4
# 1                 0             0             0                    4
# 2                 0             0             0                    3
# 3                 0             0             0                    4
# 4                 1             0             0                    4
# ...             ...           ...           ...                  ...
# 291236            0             0             0                    5
# 291237            0             0             0                    3
# 291238            2             0             0                    0
# 291239            2             0             0                    3
# 291240            1             0             0                    4
#
#         weight_restricted  road_type  start_latitude  start_longitude  \
# 0                       0          0             515              338
# 1                       0          1              91              164
# 2                       0          0              94              220
# 3                       0          0             425              349
# 4                       0          0             525              401
# ...                   ...        ...             ...              ...
# 291236                  0          0             423              210
# 291237                  0          0             181              429
# 291238                  0          0             493              256
# 291239                  0          0              67              266
# 291240                  0          0              12              313
#
#         start_turn_restricted  end_latitude  end_longitude  \
# 0                           0           524            347
# 1                           0            90            149
# 2                           0            96            220
# 3                           0           417            349
# 4                           0           509            414
# ...                       ...           ...            ...
# 291236                      0           413            209
# 291237                      0           178            431
# 291238                      1           511            258
# 291239                      0            76            268
# 291240                      0            13            313
#
#         end_turn_restricted  road_name  start_node_name  end_node_name
# 0                         1         32              163            403
# 1                         0         35              412             22
# 2                         0         36               97             95
# 3                         0         34              262            350
# 4                         0         12              153            145
# ...                     ...        ...              ...            ...
# 291236                    0         36              337             90
# 291237                    0         34              287            451
# 291238                    1         23              119            437
# 291239                    0          1               40            346
# 291240                    0         53              236            236
#
# [291241 rows x 20 columns]

# %% [markdown]
# ## 원핫 인코딩
# + 라벨 인코딩을 할 경우, 모든 칼럼을 범주형으로 간주하고 사용해도 무방하지만,<br/>
#   원핫인코딩을 하면 너무 칼럼이 많아질 수도 있다.<br/>
#   처음에는 모든 칼럼을 원핫인코딩하고, 그 후 몇몇개를 연속형데이터로 쓸지 고민해볼수도있다.

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

for i in df_col:
    le = OneHotEncoder()
    le=le.fit(train[i])
    train[i]=le.transform(train[i])
    
    for label in np.unique(test[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test[i]=le.transform(test[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12920/745766728.py in <module>
#       8 for i in df_col:
#       9     le = OneHotEncoder()
# ---> 10     le=le.fit(train[i])
#      11     train[i]=le.transform(train[i])
#      12
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     421         """
#     422         self._validate_keywords()
# --> 423         self._fit(X, handle_unknown=self.handle_unknown,
#     424                   force_all_finite='allow-nan')
#     425         self.drop_idx_ = self._compute_drop_idx()
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown, force_all_finite)
#      75
#      76     def _fit(self, X, handle_unknown='error', force_all_finite=True):
# ---> 77         X_list, n_samples, n_features = self._check_X(
#      78             X, force_all_finite=force_all_finite)
#      79
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X, force_all_finite)
#      42         if not (hasattr(X, 'iloc') and getattr(X, 'ndim', 0) == 2):
#      43             # if not a dataframe, do normal check_array validation
# ---> 44             X_temp = check_array(X, dtype=None,
#      45                                  force_all_finite=force_all_finite)
#      46             if (not hasattr(X, 'dtype')
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[242 277  39 ... 232  49  48].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
data = train["road_name"]

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
oe = ordinal_encoder.fit_transform(data)

oe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12920/678457044.py in <module>
#       2
#       3 ordinal_encoder = OrdinalEncoder()
# ----> 4 oe = ordinal_encoder.fit_transform(data)
#       5
#       6 oe
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     777                             f"got {self.unknown_value}.")
#     778
# --> 779         self._fit(X)
#     780
#     781         if self.handle_unknown == 'use_encoded_value':
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown, force_all_finite)
#      75
#      76     def _fit(self, X, handle_unknown='error', force_all_finite=True):
# ---> 77         X_list, n_samples, n_features = self._check_X(
#      78             X, force_all_finite=force_all_finite)
#      79
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X, force_all_finite)
#      42         if not (hasattr(X, 'iloc') and getattr(X, 'ndim', 0) == 2):
#      43             # if not a dataframe, do normal check_array validation
# ---> 44             X_temp = check_array(X, dtype=None,
#      45                                  force_all_finite=force_all_finite)
#      46             if (not hasattr(X, 'dtype')
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\tmdgh\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['지방도1112호선' '일반국도11호선' '일반국도16호선' ... '일반국도12호선' '일반국도95호선' '경찰로'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## BaseLine Model
# + regression
# + lightGBM
# + Gradiant Boost
# + Random Forest

# %%
# regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

y_target = train["target"]
x_data = train[df_col]

x_train, x_test, y_train, y_test = train_test_split(x_data,y_target,test_size=0.3,random_state=56)

lr = LinearRegression()
lr.fit(x_train,y_train)
pred_lr = lr.predict(x_test)
mae = mean_absolute_error(y_test,pred_lr)

print(mae)
# Out:
# 10.093224326701707

# %%
# lightGBM
from sklearn.model_selection import train_test_split
import lightgbm
from sklearn.metrics import mean_absolute_error

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

y_target = train["target"]
x_data = train[df_col]

x_train, x_test, y_train, y_test = train_test_split(x_data,y_target,test_size=0.3,random_state=56)

lgbm = lightgbm.LGBMRegressor()
lgbm.fit(x_train,y_train)
pred_lgbm = lgbm.predict(x_test)
mae = mean_absolute_error(y_test,pred_lgbm)

print(mae)
# Out:
# 4.671275180075008

# %%
# GradiantBoost
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

y_target = train["target"]
x_data = train[df_col]

x_train, x_test, y_train, y_test = train_test_split(x_data,y_target,test_size=0.3,random_state=56)

gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr = gbr.predict(x_test)
mae = mean_absolute_error(y_test,pred_gbr)

print(mae)
# Out:
# 6.516298970741768

# %%
# Random Forest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

df_col = ["base_date","base_hour","day_of_week","road_in_use","lane_count","road_rating","multi_linked","connect_code",
          "maximum_speed_limit","weight_restricted","road_type","start_latitude","start_longitude","start_turn_restricted",
          "end_latitude","end_longitude","end_turn_restricted","road_name","start_node_name","end_node_name"]

y_target = train["target"]
x_data = train[df_col]

x_train, x_test, y_train, y_test = train_test_split(x_data,y_target,test_size=0.3,random_state=56)

gbr = RandomForestRegressor(random_state=0, n_jobs=-1)
gbr.fit(x_train,y_train)
pred_gbr = gbr.predict(x_test)
mae = mean_absolute_error(y_test,pred_gbr)

print(mae)
# Out:
# 2.9119917170436613
